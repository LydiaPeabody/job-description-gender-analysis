# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
#importing raw data
jobs_original = pd.read_csv('./data/full_dataset_1.csv')

# %%
jobs_original.head()
# Out:
#                          company company_rating industry  \
# 0              ANZ Banking Group            4.1     data
# 1  NAB - National Australia Bank            3.8     data
# 2              ANZ Banking Group            4.1     data
# 3  NAB - National Australia Bank            3.8     data
# 4                          Coles            3.8     data
#
#                             job_description_all_text  \
# 0  Consultant Data Scientist – Data Activation, M...
# 1  Work type: Permanent Full time\nLocation: Aust...
# 2  The Team\n\nThe Customer Service Operations Au...
# 3  Work type: Permanent Full time\nLocation: Aust...
# 4  About Us\n\nThe Digital team is focused on rei...
#
#                    job_title salary_data_text
# 0  Data Scientist Consultant              NaN
# 1             Data Scientist              NaN
# 2      Senior Data Scientist              NaN
# 3    Data Analytics Engineer              NaN
# 4             Data Scientist              NaN

# %%
import pandas_profiling
pandas_profiling.ProfileReport(jobs_original)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>6 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>12957 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>20.2% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>607.4 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>48.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>6 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_company"><code>company</code></a> has 161 / 1.2% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_company"><code>company</code></a> has a high cardinality: 2153 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_company_rating"><code>company_rating</code></a> has 6448 / 49.8% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_job_description_all_text"><code>job_description_all_text</code></a> has a high cardinality: 5575 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_job_title"><code>job_title</code></a> has a high cardinality: 4620 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_salary_data_text"><code>salary_data_text</code></a> has 8891 / 68.6% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_salary_data_text"><code>salary_data_text</code></a> has a high cardinality: 521 distinct values  <span class="label label-warning">Warning</span></li><li>Dataset has 6934 duplicate rows <span class="label label-warning">Warning</span></li> </ul>
#     </div>
# </d

# %%
#looks like we have a lot of duplicate jobs
#not surprising from general scraping
for column in jobs_original.columns:
    print(column, jobs_original.duplicated(subset=column).sum() )
# Out:
# company 10804
# company_rating 12927
# industry 12949
# job_description_all_text 7382
# job_title 8337
# salary_data_text 12436

# %%
#starting by dropping all fully duplicate columns
jobs_original.drop_duplicates(keep='first').shape
# Out:
# (6023, 6)

# %%
#looks like this loses us over half our data!
jobs_nona = jobs_original.drop_duplicates(keep='first')

# %%
pandas_profiling.ProfileReport(jobs_nona)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>7 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>6023 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>17.5% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>329.5 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>56.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>6 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_company"><code>company</code></a> has a high cardinality: 2153 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_company_rating"><code>company_rating</code></a> has 2684 / 44.6% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_job_description_all_text"><code>job_description_all_text</code></a> has a high cardinality: 5575 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_job_title"><code>job_title</code></a> has a high cardinality: 4620 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_salary_data_text"><code>salary_data_text</code></a> has 4654 / 77.3% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_salary_data_text"><code>salary_data_text</code></a> has a high cardinality: 521 distinct values  <span class="label label-warning">Warning</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_company">company<br/>

# %%
#fully duplicated description text is likely to be a true duplicate
duplicate_jds = jobs_nona[jobs_nona.duplicated(subset='job_description_all_text')]

# %%
pandas_profiling.ProfileReport(duplicate_jds)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>7 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>448 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>17.3% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>24.6 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>56.2 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>6 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_company"><code>company</code></a> has 6 / 1.3% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_company"><code>company</code></a> has a high cardinality: 281 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_company_rating"><code>company_rating</code></a> has 174 / 38.8% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_job_description_all_text"><code>job_description_all_text</code></a> has a high cardinality: 411 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_job_title"><code>job_title</code></a> has a high cardinality: 380 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_salary_data_text"><code>salary_data_text</code></a> has 356 / 79.5% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_salary_data_text"><code>salary_data_text</code></a> has a high cardinality: 70 distinct values  <span class="label label-warning">Warning</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="

# %%
#does look like some may be the same job advertised with various titles
#why are only 37 of these considered duplicated, when all of them were before?
duplicate_jds.duplicated('job_description_all_text').sum()
# Out:
# 37

# %%
import missingno

# %%
missingno.matrix(jobs_nona)

# %%
#company rating and salary are expected to be sparse
#company is not really essential, so not concerned about missing values there
#can't do much if jd text is missing, so will drop those

jobs_nona = jobs_nona.dropna(subset=['job_description_all_text'])
jobs_nona.isna().sum()
# Out:
# company                       16
# company_rating              2679
# industry                       0
# job_description_all_text       0
# job_title                      0
# salary_data_text            4649
# dtype: int64

# %%
# Given that only 16 are missing in company, let's look at those
jobs_nona[jobs_nona.company.isna()]
# Out:
#       company company_rating       industry  \
# 490       NaN            NaN           data
# 806       NaN            NaN           data
# 2263      NaN            NaN           data
# 2413      NaN            NaN           data
# 3973      NaN            NaN   construction
# 3994      NaN            NaN   construction
# 4015      NaN            NaN   construction
# 4343      NaN            NaN   construction
# 4427      NaN            NaN   construction
# 4693      NaN            NaN   construction
# 4833      NaN            NaN  manufacturing
# 5465      NaN            NaN  manufacturing
# 5761      NaN            NaN  manufacturing
# 10302     NaN            NaN        finance
# 10317     NaN            NaN        finance
# 10565     NaN            NaN        finance
#
#                                 job_description_all_text  \
# 490    The opportunity Our client who is a market lea...
# 806    Do you have a passion for helping people with ...
# 2263   Port Melbourne Location Full-Time Perm Role Gr...
# 2413   An exciting position as a Senior Sales Analyst...
# 3973   We are Melbourne based specialist contractors ...
# 3994   We are a team of contractors providing special...
# 4015   We are Melbourne based specialist contractors ...
# 4343   Stable company, full time roles available\nOve...
# 4427   We are specialist contractors that are current...
# 4693   A great opportunity exists for a Senior Associ...
# 4833   Based in Campbellfield, your role will be to:\...
# 5465   Stable company, full time roles available\nOve...
# 5761   The opportunity Our client who is a well regar...
# 10302  We are looking for an IT Asset Manager to assi...
# 10317  An exciting position as a Senior Sales Analyst...
# 10565  We are seeing an increase in international leg...
#
#                                                job_title  \
# 490                          Salesforce Business Analyst
# 806    Helpdesk Support Analyst – Inner Northern Subu...
# 2263                         Help Desk Analyst - Level 2
# 2413                                Senior Sales Analyst
# 3973   Amrick Specialist Contractors – Construction L...
# 3994                   Construction Labourer – APPLY NOW
# 4015   Amrick Specialist Contractors – Ticketed Labou...
# 4343       Forklift Driver / Labourer / Machine Operator
# 4427   Amrick Specialist Contractors – South Eastern/...
# 4693   Construction and Infrastructure Senior Associa...
# 4833            Factory Hand / Fabrication / Storeperson
# 5465       Forklift Driver / Labourer / Machine Operator
# 5761                         Technical Solution Designer
# 10302                                      Asset Manager
# 10317                               Senior Sales Analyst
# 10565                         International Lawyer Roles
#
#                  salary_data_text
# 490             $750 - $850 a day
# 806                           NaN
# 2263                          NaN
# 2413            $600 - $640 a day
# 3973                          NaN
# 3994                          NaN
# 4015                          NaN
# 4343                          NaN
# 4427                          NaN
# 4693                          NaN
# 4833                          NaN
# 5465                          NaN
# 5761   $140,000 - $160,000 a year
# 10302  $140,000 - $150,000 a year
# 10317           $600 - $640 a day
# 10565                         NaN

# %%
#at least one of these is a duplicate - wondering if more are duplicates posted by recruiters
